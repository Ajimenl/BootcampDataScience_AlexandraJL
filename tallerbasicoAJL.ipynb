# %% [markdown]
# Taller 1 - Python Básico
# 1.1 Creación de variables

# %%
producto = input("Ingrese el nombre del producto")
precio = int(input("Ingrese el precio del producto"))
vendido = float(input("Ingrese la cantidad vendida"))
total_vendido = precio * vendido
print(f"Hola, Registraste la siguiente información:")
print(f"El producto ingresado es: {producto}, por un precio de:{precio} pesos y la cantidad de {vendido}")
print(f"para un total de: {total_vendido}")
# Out:
# Hola, Registraste la siguiente información:
# El producto ingresado es: sala, por un precio de:350000000 pesos y la cantidad de 5.0
# para un total de: 1750000000.0

# %% [markdown]
# Estructuras de Datos (Listas, Tuplas, Diccionarios)
# Crea un programa para organizar información de múltiples ventas utilizando las estructuras adecuadas según la naturaleza de los datos.
#
# Tupla: Crea una tupla con las categorías de productos permitidas en la tienda (ej. "Electrónica", "Ropa", "Alimentos"). Se usa una tupla porque las categorías de la tienda no cambian todos los días.
# Diccionario: Crea un diccionario que represente una venta específica. Debe tener las llaves: producto, categoria, precio, cantidad y total.
# Lista: Crea una lista vacía llamada registro_ventas y añade el diccionario de la venta que acabas de crear.

# %% [markdown]
# Tupla, categorias de la tienda.

# %%
items_tienda = ('Tecnología','Ropa','Belleza','Decoración','Deporte','Alimentos')
print(items_tienda)
# Out:
# ('Tecnología', 'Ropa', 'Belleza', 'Decoración', 'Deporte', 'Alimentos')

# %% [markdown]
# Diccionarios

# %%
ventas = {
        "producto":"Televisor",
        "categoria":"Tecnología",
        "precio":3550000,
        "cantidad": 5,
}
total= ventas["precio"] * ventas["cantidad"]
print(total)
# Out:
# 17750000

# %% [markdown]
# Lista: Crea una lista vacía llamada registro_ventas y añade el diccionario de la venta que acabas de crear.

# %%
registro_ventas = [ventas]
registro_ventas.append ({'producto': 'sala', 'categoria': 'Decoración', 'precio': 1950000, 'cantidad': 2})
registro_ventas.append ({'producto': 'comedor', 'categoria': 'Decoración', 'precio': 1250000, 'cantidad': 3})
registro_ventas.append ({'producto': 'computador', 'categoria': 'Tecnología', 'precio': 900000, 'cantidad': 7})
print(registro_ventas)
# Out:
# [{'producto': 'Televisor', 'categoria': 'Tecnología', 'precio': 3550000, 'cantidad': 5}, {'producto': 'sala', 'categoria': 'Decoración', 'precio': 1950000, 'cantidad': 2}, {'producto': 'comedor', 'categoria': 'Decoración', 'precio': 1250000, 'cantidad': 3}, {'producto': 'computador', 'categoria': 'Tecnología', 'precio': 900000, 'cantidad': 7}]

# %% [markdown]
# Estructuras de Control (Condicionales y Ciclos)
# Crea un ciclo for que recorra tu lista de registro_ventas (puedes agregar un par de ventas manuales extra al código para hacer la prueba).

# %%
for item in registro_ventas:
 if item["precio"] >= 1000000:
  descuento = item["precio"]*0.90
  print(f"El producto que cumple con este precio es: {item["producto"]} {item["precio"]} - precio con descuento: {descuento} ")
# Out:
# El producto que cumple con este precio es: Televisor 3550000 - precio con descuento: 3195000.0
# El producto que cumple con este precio es: sala 1950000 - precio con descuento: 1755000.0
# El producto que cumple con este precio es: comedor 1250000 - precio con descuento: 1125000.0

# %% [markdown]
# Funciones y Manejo de Errores
#
# Crea una función llamada calcular_ingreso que reciba dos parámetros: precio y cantidad.
# Dentro de la función, utiliza un bloque try-except. Intenta multiplicar el precio por la cantidad.
# Si ocurre un error (por ejemplo, si en lugar de un número llega un texto), el except debe atraparlo, imprimir "Error: Los valores deben ser numéricos" y retornar 0.
# Prueba tu función enviando valores correctos y luego enviando un texto para ver cómo se maneja el error.

# %%
def calcular_ingreso(precio,cantidad):
    try:
        ingreso = precio * cantidad
        return ingreso
    except (TypeError,NameError,SyntaxError):
        print("Error: Los valores deben ser numéricos")
        return 0

print(calcular_ingreso(10,10))
# Out:
# 100
